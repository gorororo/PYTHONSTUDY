# %%
from tkinter import *

win = Tk()
win.geometry("300x200")
win.title("창생성")
win.config(bg='#eee')



btn = Button(win)
btn.place(x=20, y=20, width=100, height=50)
btn2 = Button(win)
btn2.place(x=130, y=20, width=100, height=50)

lbl = Label(win)
lbl.config(text='hello python',width=10,height=5,fg='#111',relief='ridge',font=("",8,""))
# font=("글자체",글자크기."글자모양")
lbl.place(x=25,y=25,width=90,height=40)


win.mainloop()

# %%
from tkinter import *

win = Tk()
win.geometry('300x200')
win.title('버튼만들기')
win.config(bg='#eee')
key = 0
def call():
    global key
    if key == 0:
        btnClick.config(text='Python')
        key = 1
    else:
        btnClick.config(text='Click')
        key = 0

# lblcall = Label(win)
# lblcall.config(relief='ridge',text='hello python',font=("",8,""))
# lblcall.place(x=10,y=30,width=50,height=20)

btnClick = Button(win)
btnClick.config(text='Click', command=call)
btnClick.place(x=10,y=10,width=50,height=20)
                   
win.mainloop()

# %%
x=10
def op():
    x= 20
    print('op:',x)
    
op()
print('main:',x)
# Out:
# op: 20
# main: 10

# %%
x=10
def op():
    global x
    x= 20
    print('op:',x)
    
op()
print('main:',x)
# Out:
# op: 20
# main: 20

# %%
from tkinter import *

root = Tk()
root.geometry('300x200')
root.config(bg='#eee')

def Click():
    a = int(et.get())
    if a %2 == 1 :
        lblcall.config(text='홀수')
    else :
        lblcall.config(text='짝수')
    
et = Entry(root)
et.pack()
et.place(x=10,y=10,width=50,height=20)

    
btnClick = Button(root)
btnClick.config(text='홀/짝',command='Click')
btnClick.place(x=70,y=10,width=50,height=20)


lblcall = Label(root)
lblcall.config(relief='ridge',font=("",8,""))
lblcall.place(x=130,y=10,width=50,height=20)



root.mainloop()

# %%
from tkinter import *
from tkinter import messagebox
 
root = Tk()
 
# 버튼 클릭 이벤트 핸들러
def okClick():
    name = txt.get()
    messagebox.showinfo("이름", name)
 
lbl = Label(root, text="이름")
lbl.grid(row=0, column=0)
txt = Entry(root)
txt.grid(row=0, column=1)
 
# 버튼 클릭 이벤트와 핸들러 정의
btn = Button(root, text="OK", command=okClick)
 
btn.grid(row=1, column=1)
 
root.mainloop()

# %%
from tkinter import *
root = Tk()
 
def click(event):
    print("클릭위치", event.x, event.y)
 
frame = Frame(root, width=300, height=300)
 
 #왼쪽 마우스 버튼 바인딩
frame.bind("<Button-1>", click) 
 
frame.pack()
root.mainloop()

# %%
from tkinter import *
from tkinter import ttk

# Tkinter 인스턴스 생성
win = Tk()

# Window 사이즈 지정
win.geometry("300x200+100+100")
win.resizable(False, False)

# get() : entry에 텍스트를 문자열로 반환
def Cal():
    a = int(entry.get())
    if a %2 == 1 :
        label.config(text='홀수')
    else :
        label.config(text='짝수')


entry = Entry(win)
entry.pack()

button = Button(win, text="계산", command=Cal)
button.pack()

label = Label(win)
label.pack()

win.mainloop()

# %%
from tkinter import *

root = Tk()
root.geometry('300x200')
root.config(bg='#eee')

def Click():
    a = int(et.get())
    if a %2 == 1 :
        lblcall.config(text='홀수')
    else :
        lblcall.config(text='짝수')
    
et = Entry(root)
et.pack()
et.place(x=10,y=10,width=50,height=20)

    
btnClick = Button(root)
btnClick.config(text='홀/짝',command=Click)
btnClick.place(x=70,y=10,width=50,height=20)


lblcall = Label(root)
lblcall.config(relief='ridge',font=("",8,""))
lblcall.place(x=130,y=10,width=50,height=20)



root.mainloop()

# %%
from tkinter import *
import random

root = Tk()
root.geometry('300x200')
root.config(bg='#eee')

def ClickLotto():
    lotto = random.sample(range(1,46),6) 
#     lotto.sort(reverse=True)
    lotto.sort()
    lbl.config(text=lotto) 
    
lbl = Label(root)
lbl.config(relief='ridge',font=("",8,""))
lbl.place(x=10,y=10,width=200,height=20)

btn = Button(root)
btn.config(text='Lotto',command=ClickLotto)
btn.place(x=10,y=30,width=200,height=20)

root.mainloop()

# %%
from tkinter import*
from tkinter import ttk
from functools import partial


root = Tk()
root.geometry('300x160')
root.config(bg='#eee')
m_num=0

def click(key):
    global m_num
    if key=='+':
        m_num+=1
    elif key =='-':
        m_num-=1
    else:
        m_num=0
    lbl.config(text=m_num)
        
        
lbl = Label(root)
lbl.config(relief='ridge',font=("",8,""))
lbl.place(x=100,y=10,width=100,height=20)

btn1 = Button(root)
btn1.config(text='+',command=partial(click,'+'))
btn1.place(x=100,y=30,width=100,height=40)

btn2 = Button(root)
btn2.config(text='-',command=partial(click,'-'))
btn2.place(x=100,y=70,width=100,height=40)

btn3 = Button(root)
btn3.config(text='Reset',command=partial(click,'Reset'))
btn3.place(x=100,y=110,width=100,height=40)

root.mainloop()

# %%
from tkinter import*
from tkinter import ttk

win = Tk()
win.geometry('500x500')


cnt=0

def numAdd():
    global cnt
    cnt = cnt + 1
    lbl.config(text=cnt)


def numSub():
    global cnt
    cnt = cnt - 1
    lbl.config(text=cnt)
    
    
lbl = Label(win)
lbl.config(text='?',justify=CENTER, relief=RIDGE)
lbl.place(x=10, y=10,width=100,height=50)

btnp = Button(win)
btnp.config(text="+",font=("",8,""),command=numAdd)
btnp.place(x=10, y=70, width=100,height=50)
            
btnp2 = Button(win)
btnp2.config(text="-",font=("",8,""),command=numSub)
btnp2.place(x=10, y=130, width=100,height=50)

win.mainloop()

# %%
from tkinter import *
from tkinter import ttk

incr=Tk()
incr.title("increasing_numbers")

m_num=0
#버튼 명령
def click(key):
    global m_num
    if key=='+':
        m_num+=1
    elif key=='-':
        m_num-=1
    else:
        m_num=0
    num_var.set(m_num)

#라벨 생성
num_var=IntVar()
w=Label(incr, textvariable=num_var)
w.grid(row=0)

#+,-,리셋 버튼생성
operator_list=['+','-','reset']

r=1
for btn_text in operator_list:
    def cmd(x=btn_text):
        click(x)
    ttk.Button(incr,text=btn_text,command=cmd).grid(row=r)
    r+=1


incr.mainloop()

# %%
from tkinter import *
from tkinter import ttk

win = Tk()
win.title('계산프로그램')

#라벨 생성
# eval(Entry.get())

def Cal():
    num = eval(entry.get())
    lbl.config(text = num)

lbl = Label(win)
lbl.config(text="",justify=CENTER, relief=RIDGE)
lbl.place(x=10, y=10,width=150,height=25)

entry = Entry(win)
entry.config(text="",font=("",8,""))
entry.place(x=10, y=40, width=150,height=25)

btnp = Button(win)
btnp.config(text="계산결과",font=("",8,""),command=Cal)
btnp.place(x=10, y=75, width=150,height=25)

win.mainloop()

# %%
from tkinter import *
from tkinter import ttk
import random
# 윈도우 창 설정
win = Tk()
win.title('숫자찾기게임')
win.geometry('330x150')

# 변수설정
num = 0
betNum = random.randint(1,100)
cnt = 0

# 함수 설정
def NumGame():
    global num
    global betNum
    global cnt
    cnt+=1
    btnp['text'] = f'클릭 했습니다.'
    lblcnt.config(text=f'횟수 : {cnt}')
    
    num = int(entry.get())
    if num < betNum:
        lbl2['text'] = num
    elif num > betNum:
        lbl3['text'] = num
    else:
#         lbl1.config(text=f'정답: {num}')
        lbl1['text'] = f'정답 : {num}'
    
        
def reset():
    global num
    global betNum
    global cnt
    
    num = 0
    cnt = 0
    
    entry.delete(0,END)
    lbl1.config(text="")
    lbl2.config(text="0")
    lbl3.config(text="100")
    lblcnt.config(text="횟수")
    betNum = random.randint(1,100)
    btnp['text'] = "클릭"

            
        
# 버튼생성    

lblname1 = Label(win)
lblname1.config(text='COM',justify=CENTER)
lblname1.place(x=10, y=10,width=100,height=25)

lblname2 = Label(win)
lblname2.config(text='작은수',justify=CENTER)
lblname2.place(x=115, y=10,width=100,height=25)

lblname3 = Label(win)
lblname3.config(text='큰수',justify=CENTER)
lblname3.place(x=220, y=10,width=100,height=25)
    
lbl1 = Label(win)
lbl1.config(text='?',justify=CENTER, relief=RIDGE)
lbl1.place(x=10, y=35,width=100,height=25)

lbl2 = Label(win)
lbl2.config(text='0',justify=CENTER, relief=RIDGE)
lbl2.place(x=115, y=35,width=100,height=25)

lbl3 = Label(win)
lbl3.config(text='100',justify=CENTER, relief=RIDGE)
lbl3.place(x=220, y=35,width=100,height=25)

lbl4 = Label(win)
lbl4.config(text='입력수치',justify=CENTER)
lbl4.place(x=10, y=75,width=100,height=25)

entry = Entry(win)
entry.config(text="",font=("",8,""))
entry.place(x=115, y=75,width=100,height=25)

btnp = Button(win)
btnp.config(text="확인",font=("",8,""),command=NumGame)
btnp.place(x=220, y=75,width=100,height=25)

rebtn = Button(win)
rebtn.config(text="게임을 다시시작",font=("",8,""),command=reset)
rebtn.place(x=220, y=110,width=100,height=25)

lblcnt = Label(win)
lblcnt.config(text='횟수',justify=CENTER)
lblcnt.place(x=10, y=110,width=100,height=25)

win.mainloop()

# %%
from tkinter import *
from functools import partial

win = Tk()
win.geometry("250x340")

def fun_call(str_in):
    lbl.config(text=str_in, font=("",15,"bold"))
    lbl.place(x=10, y=10, width=210, height=100)
    
    
img = [ PhotoImage(file='D:/gorororo/PYTHONSTUDY/training/lion.png'),
        PhotoImage(file='D:/gorororo/PYTHONSTUDY/training/Penguin.png'),
        PhotoImage(file='D:/gorororo/PYTHONSTUDY/training/Rhinoceros.png'),
        PhotoImage(file='D://gorororo/PYTHONSTUDY/training/panda.png')]


lbl = Label(win, text='Hello')
lbl.config(relief='ridge')
lbl.place(x=10, y=10,width=210,height=100)
lbl.config(bg=('#00FF00'),fg="#0000FF",font=("",15,""))

btn1 = Button(win,image=img[0])
btn1.place(x=10, y=120,width=100, height=100)
btn1.config(command=partial(fun_call,"사자"))

btn2 = Button(win,image=img[1])
btn2.place(x=120, y=120,width=100, height=100)
btn2.config(command=partial(fun_call,"팽귄"))

btn3 = Button(win,image=img[2])
btn3.place(x=10, y=230,width=100, height=100)
btn3.config(command=partial(fun_call,"코뿔소"))

btn4 = Button(win,image=img[3])
btn4.place(x=120, y=230,width=100, height=100)
btn4.config(command=partial(fun_call,"팬더"))

win.mainloop()

# %%
from tkinter import *
import random

win = Tk()
win.geometry('610x250')

num1= 0
num2= 0

print(op)

def rndnum():
    global num1
    global num2
    op = random.randint(1,4)
    num1 = random.randint(1,11)
    num2 = random.randint(1,11)
    # if op == 1:
    #     lbl2.config(text='+')
    # elif op == 2:
    #     lbl2.config(text='-')
    # elif op == 2:
    #     lbl2.config(text='*')
    # elif op == 4:
    #     lbl2.config(text='/')

    if num1 >= num2:
        lbl1.config(text=num1)
        lbl3.config(text=num2)
    else:
        lbl1.config(text=num2)
        lbl3.config(text=num1)
    
    btnresult.config(text='정답확인')
    lbl2.config(text='+-*/')
    btnstart.config(text='+ - * / 중에 답을 적으시오')

    ety.delete(0,END)

def answer():
    
    if num1 + num2 ==int(ety.get()):
        btnresult.config(text='덧셈 정답 입니다')
        lbl2.config(text='+')
    elif num1 - num2 ==int(ety.get()):
        btnresult.config(text='빼기 정답 입니다')
        lbl2.config(text='-')
    elif num1 * num2 ==int(ety.get()):
        btnresult.config(text='곱셈 정답 입니다')
        lbl2.config(text='*')
    elif num1 / num2 == int(ety.get()):
        btnresult.config(text='나누셈 정답 입니다')
        lbl2.config(text='/')
    else:
        btnresult.config(text='오답')
        



lbl1 = Label(win)
lbl1.config(text='?',relief='ridge',justify='center',font=("",40,""))
lbl1.place(x=10,y=10, width=100,height=100)

lbl2 = Label(win)
lbl2.config(text='+-*/',relief='ridge',justify='center',font=("",18,""))
lbl2.place(x=120,y=10, width=100,height=100)

lbl3 = Label(win)
lbl3.config(text='?',relief='ridge',justify='center',font=("",40,""))
lbl3.place(x=230,y=10, width=100,height=100)

lbl4 = Label(win)
lbl4.config(text='=',relief='ridge',justify='center',font=("",40,""))
lbl4.place(x=340,y=10, width=100,height=100)

ety = Entry(win)
ety.config(relief="ridge",justify='center',font=("",40,""))
ety.place(x=450, y=10, width=150,height=100)

btnstart = Button(win)
btnstart.config(text='숫자 생성' ,font=("",15,""),command=rndnum)
btnstart.place(x=10,y=140,width=320,height=100)

btnresult = Button(win)
btnresult.config(text='정답확인',font=("",20,""),command=answer)
btnresult.place(x=340, y=140,width=260,height=100)

win.mainloop()
# Out:
# 2

# %%
import tkinter as tk

root = tk.Tk()
root.title("Tkinter Calculator")
root.geometry("350x500")

upper_frame = tk.Frame(root, width=400, height=70)
upper_frame.pack(pady=40)

down_frame = tk.Frame(root, width=400, height=100)
down_frame.pack(padx=10, pady=10)

entry = tk.Entry(upper_frame, width=20, font=("Courier",18), borderwidth=5)
entry.pack()
entry.insert(0,"")

def button_clicked(number):
    current = entry.get()
    entry.delete(0, tk.END)
    entry.insert(0, str(current) + str(number))

def button_clear():
    entry.delete(0, tk.END)

def button_add():
    first_number = entry.get()
    global f_num
    global math
    math = 'addition'
    f_num = int(first_number)
    entry.delete(0, tk.END)

def button_sub():
    first_number = entry.get()
    global f_num
    global math
    math = 'subtraction'
    f_num = int(first_number)
    entry.delete(0, tk.END)

def button_mul():
    first_number = entry.get()
    global f_num
    global math
    math = 'multiplication'
    f_num = int(first_number)
    entry.delete(0, tk.END)

def button_div():
    first_number = entry.get()
    global f_num
    global math
    math = 'division'
    f_num = int(first_number)
    entry.delete(0, tk.END)

def button_equal():
    second_number = entry.get()
    entry.delete(0, tk.END)

    if math == 'addition':
        entry.insert(0,f_num + int(second_number))

    if math == 'subtraction':
        entry.insert(0,f_num - int(second_number))

    if math == 'multiplication':
        entry.insert(0,f_num * int(second_number))

    if math == 'division':
        entry.insert(0,f_num / int(second_number))


btn7 = tk.Button(down_frame,text='7', padx=15, pady=10, font=("Courier",15),command=lambda: button_clicked(7))
btn7.grid(column=0, row=0, padx=5, pady=5)
btn8 = tk.Button(down_frame,text='8', padx=15, pady=10, font=("Courier",15),command=lambda: button_clicked(8))
btn8.grid(column=1, row=0, padx=5, pady=5)
btn9 = tk.Button(down_frame,text='9', padx=15, pady=10, font=("Courier",15),command=lambda: button_clicked(9))
btn9.grid(column=2, row=0, padx=5, pady=5)

btn4 = tk.Button(down_frame,text='4', padx=15, pady=10, font=("Courier",15),command=lambda: button_clicked(4))
btn4.grid(column=0, row=1, padx=5, pady=5)
btn5 = tk.Button(down_frame,text='5', padx=15, pady=10, font=("Courier",15),command=lambda: button_clicked(5))
btn5.grid(column=1, row=1, padx=5, pady=5)
btn6 = tk.Button(down_frame,text='6', padx=15, pady=10, font=("Courier",15),command=lambda: button_clicked(6))
btn6.grid(column=2, row=1, padx=5, pady=5)

btn1 = tk.Button(down_frame,text='1', padx=15, pady=10, font=("Courier",15),command=lambda: button_clicked(1))
btn1.grid(column=0, row=2, padx=5, pady=5)
btn2 = tk.Button(down_frame,text='2', padx=15, pady=10, font=("Courier",15),command=lambda: button_clicked(2))
btn2.grid(column=1, row=2, padx=5, pady=5)
btn3 = tk.Button(down_frame,text='3', padx=15, pady=10, font=("Courier",15),command=lambda: button_clicked(3))
btn3.grid(column=2, row=2, padx=5, pady=5)

btn_pm = tk.Button(down_frame,text='+/-', padx=5, pady=10, font=("Courier",15),command=lambda: button_clicked('-'))
btn_pm.grid(column=0, row=3, padx=5, pady=5)
btn0 = tk.Button(down_frame,text='0', padx=15, pady=10, font=("Courier",15),command=lambda: button_clicked(0))
btn0.grid(column=1, row=3, padx=5, pady=5)
btn_p = tk.Button(down_frame,text='.', padx=15, pady=10, font=("Courier",15),command=lambda: button_clicked('.'))
btn_p.grid(column=2, row=3, padx=5, pady=5)

btn_mul = tk.Button(down_frame,text='X', padx=15, pady=10, font=("Courier",15),command=button_mul, bg='orange')
btn_mul.grid(column=3, row=0, padx=5, pady=5)
btn_sub = tk.Button(down_frame,text='-', padx=15, pady=10, font=("Courier",15),command=button_sub, bg='orange')
btn_sub.grid(column=3, row=1, padx=5, pady=5)
btn_add = tk.Button(down_frame, text='+', padx=15, pady=10, font=("Courier",15),command=button_add, bg='orange')
btn_add.grid(column=3, row=2, padx=5, pady=5)
btn_div = tk.Button(down_frame, text='/', padx=15, pady=10, font=("Courier",15),command=button_div, bg='orange')
btn_div.grid(column=3, row=3, padx=5, pady=5)

btn_c = tk.Button(down_frame, text='C', padx=15, pady=10, font=("Courier",15),command=button_clear, bg='orange')
btn_c.grid(column=2, row=4, padx=5, pady=5)

btn_res = tk.Button(down_frame, text='=', padx=15, pady=10, font=("Courier",15),command=button_equal, bg='orange')
btn_res.grid(column=3, row=4, padx=5, pady=5)

btn3 = tk.Button(root,text='9')

root.mainloop()

# %%
import tkinter as tk
from functools import partial
win = tk.Tk()

st= ''
clear_st = 0

def gugudan(dan):
    global st
    st= ''
    for i in range(1,10):
        st = st +str(dan) + '*' +str(i) + ' = ' + str(i*dan) + '\n'
        lbl.config(text=st)

# def reset(): 
#     global st
#     st = ''
    
    

# btn_clear = Button(height=1, text='초기화',justify='center',font=("",10,""),command=reset)
# btn_clear.place(x=130,y=175)
lbl= Label(win,relief='ridge')
lbl.config(text='구구단', relief='ridge',justify='center',font=("",10,""))
lbl.place(x=0,y=0)
btn2 = Button(height=1, text='2단', command=partial(gugudan,2))
btn2.place(x=65,y=0)
btn3 = Button(height=1, text='3단', command=partial(gugudan,3))
btn3.place(x=65,y=25)
btn4 = Button(height=1, text='4단', command=partial(gugudan,4))
btn4.place(x=65,y=50)
btn5 = Button(height=1, text='5단', command=partial(gugudan,5))
btn5.place(x=65,y=75)
btn6 = Button(height=1, text='6단', command=partial(gugudan,6))
btn6.place(x=65,y=100)
btn7 = Button(height=1, text='7단', command=partial(gugudan,7))
btn7.place(x=65,y=125)
btn8 = Button(height=1, text='8단', command=partial(gugudan,8))
btn8.place(x=65,y=150)
btn9 = Button(height=1, text='9단', command=partial(gugudan,9))
btn9.place(x=65,y=175)

win.mainloop()

# %%
# for vRow in range(0,3,1):
#     for vColumn in range(0,3,1): range()
#         vButton=Button(win)
#         vButton.config(text= f'{vRow},{vColumn}')
#         vButton.grid(row=vRow, column=vColumn)

# %%
import tkinter as tk
from PIL import ImageTk

bg_color = '#009688'

# initiallize app
root = tk.Tk()
root.title("recipe Picker")

#root.eval("tk::PlaceWindow.center")
x=root.winfo_screenwidth() //2
y=int(root.winfo_screenheight() * 0.1)
root.geometry('500x600+' + str(x) + '+' + str(y))
#create a frame widget
frame1 = tk.Frame(root, width=500,height=600,bg='#009688')
frame1.grid(row=0,column=0)
frame1.pack_propagate(False)

# frame1 widgets
logo_img=ImageTk.PhotoImage(file="./logogr.png")
logo_widget = tk.Label(frame1, image=logo_img, bg='#009688')
logo_widget.image = logo_img
logo_widget.pack()

tk.Label(frame1, 
        text="ready for your random recipe?",
        bg= bg_color,
        fg='white',
        font=('TkMenuFont',14,"bold")
        ).pack()

logo_widget.pack()
root.mainloop()
